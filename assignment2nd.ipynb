# %% [markdown]
# ##### Assignment 1:
# ##### Date : 14th May 2026
# ##### opic – Python Fundamentals

# %% [markdown]
# ##### 1. Write a Python program to print your name, course, and city using proper formatting.

# %%
print("Name   : Harsh")
print("Course : Python")
print("City   : Jaipur")
# Out:
# Name   : Harsh
# Course : Python
# City   : Jaipur

# %% [markdown]
# ##### Q.2Take user input for name and age, then print: "Hello <name>, you are <age> years old"

# %%
name = input("Enter your name: ")
age = input("Enter your age: ")
print("Hello", name + ", you are", age, "years old")

# %% [markdown]
# ##### Q.3Write a program to: ● Take a string input  ● Print its reverse  ● Count total number of characters

# %%
text = input("Enter a string: ")
print("Reverse:", text[::-1])

print("Total Characters:", len(text))
