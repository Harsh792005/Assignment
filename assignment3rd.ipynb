# %% [markdown]
# ##### Assignment 3:
# ##### Date : 15/05/2026
# ##### Topic – python list & String
#
# ##### Q.1 Write a program to declare variables of different data types and print them.

# %%
a = 10 
print("Integer:", a)           
b = 5.5 
print("Float:", b)         
c = "Python" 
print("String:", c)     
d = True
print("Boolean:", d)
# Out:
# Integer: 10
# Float: 5.5
# String: Python
# Boolean: True

# %% [markdown]
# ##### Q.2 Write a program to create a string and perform operations like uppercase, lowercase, and length check.

# %%
text = "My name is harsh"
print("Uppercase:", text.upper())
print("Lowercase:", text.lower())
print("Length:", len(text))
# Out:
# Uppercase: MY NAME IS HARSH
# Lowercase: my name is harsh
# Length: 16

# %% [markdown]
# ##### Q.3 Write a program to create a list of numbers and print its elements using indexing

# %%
numbers = [10, 20, 30, 40, 50]
print(numbers[0])
print(numbers[1])
print(numbers[2])
print(numbers[3])
print(numbers[4])
# Out:
# 10
# 20
# 30
# 40
# 50

# %% [markdown]
# ##### 4. Write a program to concatenate two strings and store the result in a variable.

# %%
str1 = "Hello "
str2 = "World"
result = str1 + str2
print(result)
# Out:
# Hello World

# %% [markdown]
# ##### Q.5 Write a program to create a list of student names and add a new name into the list.

# %%
students = ["Rohit", "Amit", "Neha"]
students.append("Harsh")
print(students)
# Out:
# ['Rohit', 'Amit', 'Neha', 'Harsh']

# %% [markdown]
# ##### End Assignment : 3
